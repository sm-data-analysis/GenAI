# %% [markdown]
# # Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ### Imports

# %%
import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ### Config LLM

# %%
from crewai import LLM

llm=LLM(
    model="ollama/llama3.2:1b", 
    base_url="http://localhost:11434"
)

# %% [markdown]
# ### Loading Task and Agent Yaml File

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ### Creating Pydentic Model for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ### Create Crew, Agent and Task

# %%
# Creating Agents
project_planning_agent = Agent(
  llm = llm,
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  llm = llm,
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  llm = llm,
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# 2024-11-01 18:10:36,569 - 3836 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %% [markdown]
# ### Crew's Input

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ### Starting Crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# my best complete final answer to the task
#
# Thought: Create a responsive design that works well on desktop and mobile devices
# - Task ID: 1.1
# - Description: Design a user-friendly interface with a modern, visually appealing layout that adapts to different screen sizes.
# - Scope:
#   - Develop a visually appealing layout for the website's homepage and other key pages.
#   - Ensure consistent typography, color schemes, and imagery across all web pages.
#   - Implement responsive design principles to ensure a seamless user experience on desktop and mobile devices.
# - Timeline: Task 1.1 will be completed within 3 working days.
# - Dependencies:
#   - Task 1.2 (User Interface Development) must complete before Task 1.1.
# - Deliverables:
#   - A visual representation of the responsive design concept, including wireframes and high-fidelity designs.
#
# Thought: Implement a modern, visually appealing user interface with a clean look
# - Task ID: 1.2
# - Description: Design a modern, visually appealing user interface that showcases the company's brand identity.
# - Scope:
#   - Develop a UI design that incorporates typography, color schemes, and imagery that aligns with the company's brand guidelines.
#   - Ensure consistent UI elements throughout all web pages.
# - Timeline: Task 1.2 will be completed within 4 working days.
# - Dependencies:
#   - Task 1.3 (User Interface Development) must complete before Task 1.2.
# - Deliverables:
#   - A visual representation of the modern, visually appealing user interface concept, including wireframes and high-fidelity designs.
#
# Thought: Develop a user-friendly navigation system with intuitive menu structure
# - Task ID: 1.3
# - Description: Design a user-friendly navigation system that allows for easy access to key pages.
# - Scope:
#   - Develop a hierarchical menu structure with clear labels and concise descriptions.
#   - Ensure consistent navigation patterns throughout all web pages.
# - Timeline: Task 1.3 will be completed within 2 working days.
# - Dependencies:
#   - Task 1.4 (Content Development) must complete before Task 1.3.
# - Deliverables:
#   - A visual representation of the user-friendly navigation system concept, including wireframes and high-fidelity designs.
#
# Thought: Include an "About Us" page highlighting the company's history and values
# - Task ID: 2.1
# - Description: Create a comprehensive "About Us" page that showcases the company's story.
# - Scope:
#   - Develop a detailed section on company history, mission statements, and core values.
#   - Ensure concise and clear language throughout all content.
# - Timeline: Task 2.1 will be completed within 5 working days.
# - Dependencies:
#   - Task 2.2 (Content Development) must complete before Task 2.1.
# - Deliverables:
#   - A visual representation of the "About Us" page concept, including text and image descriptions.
#
# Thought: Design a "Services" page showcasing the business's offerings with descriptions
# - Task ID: 3.1
# - Description: Develop a comprehensive Services page that showcases the company's services.
# - Scope:
#   - Create detailed sections on each service offered, including descriptions, images, and relevant information.
#   - Ensure consistent formatting throughout all content.
# - Timeline: Task 3.1 will be completed within 4 working days.
# - Dependencies:
#   - Task 2.3 (Content Development) must complete before Task 3.1.
# - Deliverables:
#   - A visual representation of the Services page concept, including text descriptions and images.
#
# Thought: Create a "Contact Us" page with a form and integrated map for communication
# - Task ID: 4.1
# - Description: Design a responsive Contact Us page that allows for easy form submission and map integration.
# - Scope:
#   - Develop a simple contact form that captures essential information from visitors.
#   - Integrate a Google Map to provide location-based directions and maps.
# - Timeline: Task 4.1 will be completed within 2 working days.
# - Dependencies:
#   - Task 3.2 (Content Development) must complete before Task 4.1.
# - Deliverables:
#   - A visual representation of the Contact Us page concept, including wireframes and high-fidelity designs.
#
# Thought: Implement a blog section for sharing industry news and company updates
# - Task ID: 5.1
# - Description: Develop a blog section that showcases the company's expertise in various industries.
# - Scope:
#   - Create detailed sections on each industry-related topic, including articles, images, and relevant information.
#   - Ensure consistent formatting throughout all content.
# - Timeline: Task 5.1 will be completed within 3 working days.
# - Dependencies:
#   - Task 4.2 (Content Development) must complete before Task 5.1.
# - Deliverables:
#   - A visual representation of the blog section concept, including text descriptions and images.
#
# Thought: Ensure fast loading times and optimize for search engines (SEO)
# - Task ID: 6.1
# - Description: Optimize all web pages for SEO by implementing relevant meta tags and improving content quality.
# - Scope:
#   - Research and implement relevant SEO best practices to improve page crawl rates and ranking.
#   - Ensure consistent formatting throughout all content.
# - Timeline: Task 6.1 will be completed within 2 working days.
# - Dependencies:
#   - Task 5.3 (Content Development) must complete before Task 6.1.
# - Deliverables:
#   - A visual representation of the optimized website concept, including high-fidelity designs and SEO-friendly code.
#
# Thought: Integrate social media links and sharing capabilities
# - Task ID: 7.1
# - Description: Add social media buttons to all web pages to enable easy sharing on various platforms.
# - Scope:
#   - Research and implement relevant social media APIs for seamless integration.
#   - Ensure consistent formatting throughout all content.
# - Timeline: Task 7.1 will be completed within 3 working days.
# - Dependencies:
#   - Task 6.2 (Content Development) must complete before Task 7.1.
# - Deliverables:
#   - A visual representation of the social media sharing section concept, including wireframes and high-fidelity designs.
#
# Thought: Develop a responsive design that adapts to different screen sizes
# - Task ID: 8.1
# - Description: Ensure all web pages are fully responsive, providing an optimal user experience across various devices.
# - Scope:
#   - Use responsive CSS frameworks to implement layout adjustments for different screen sizes.
# - Timeline: Task 8.1 will be completed within 2 working days.
# - Dependencies:
#   - No other tasks depend on this task.
#
# Thought: Test and validate the website for functionality and performance
# - Task ID: 9.1
# - Description: Conduct thorough testing of all web pages to ensure they function correctly and meet quality standards.
# - Scope:
#   - Test and validate each page, including content, form submission, and navigation.
#   - Identify and fix any issues that arise during testing.
# - Timeline: Task 9.1 will be completed within 3 working days.
# - Dependencies:
#   - No other tasks depend on this task.
#
# This list represents a comprehensive set of tasks to build a fully functional website from scratch. It covers various aspects, including design, development, and optimization for SEO. Each task is assigned to specific days to ensure timely completion and adherence to the project timeline.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# Task 1: Design the homepage
#
# The design of the homepage is crucial in establishing a strong first impression on visitors. A well-designed homepage should include a clear call-to-action (CTA), prominent navigation, and visually appealing elements such as images and text.
#
# Action: Research and create a wireframe for the homepage using a tool like Sketch or Figma.
#
#  Task 2: Develop the blog section
#
# The blog section is an essential feature in any website, providing valuable content to users and helping establish the company's authority in the industry. The development of the blog section involves creating detailed sections on various topics, including articles, images, and relevant information.
#
# Action: Use a content management system (CMS) like WordPress or Drupal to create the blog section.
#
#  Task 3: Implement social media sharing capabilities
#
# Social media integration is vital for promoting the website and engaging with users. The implementation of social media sharing capabilities involves adding buttons to all web pages that allow visitors to share content on various platforms.
#
# Action: Use a JavaScript library like IntersectionObserver to detect when a button is clicked, then use the API provided by the social media platform to share the content.
#
#  Task 4: Optimize the website for search engines (SEO)
#
# Search Engine Optimization (SEO) is crucial in increasing the website's visibility and ranking in search engine results pages. The optimization of the website involves researching and implementing relevant SEO best practices, including meta tags, header tags, and content quality.
#
# Action: Conduct a thorough analysis of the website's technical structure using tools like Google Search Console and use SEO-friendly code to improve page crawl rates and ranking.
#
#  Task 5: Develop fast loading times and optimize for search engines (SEO)
#
# Fast loading times are essential in providing an optimal user experience. The development of optimized versions of all web pages involves implementing relevant meta tags, header tags, and content quality.
#
# Action: Optimize the website's HTML code using tools like Google Lighthouse to identify areas that need improvement.
#
#  Task 6: Test and validate the website for functionality and performance
#
# Testing and validation involve ensuring that the website functions correctly and meets quality standards. The testing of the website involves checking for errors, bugs, and compatibility issues with various browsers and devices.
#
# Action: Use a tool like Cypress or Playwright to automate the testing process.
#
#  Task 7: Implement responsive design
#
# Responsive design is crucial in providing an optimal user experience across different screen sizes. The implementation of responsive CSS frameworks involves adjusting layout adjustments for different screen sizes.
#
# Action: Use a framework like Bootstrap to create responsive layouts.
#
#  Task 8: Test and validate the website's functionality
#
# The testing and validation of the website involve checking for errors, bugs, and compatibility issues with various browsers and devices.
#
# Action: Conduct thorough testing using tools like Selenium or Cypress.
#
#  Task 9: Finalize the development and deployment process
#
# After completing all tasks, the final step is to finalize the development and deployment process. This involves testing the website thoroughly, ensuring that it meets quality standards, and deploying it on a production server.
#
# Action: Conduct a comprehensive test suite using tools like End-to-End Testing (E2ET) to ensure that the website functions correctly.
#
#  Task 10: Launch and maintain the website
#
# The final step is to launch the website and maintain it over time. This involves monitoring traffic, user engagement, and performance metrics to ensure that the website continues to meet customer needs.
#
# Action: Set up analytics tools like Google Analytics to track user behavior and monitor performance metrics.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# Resource Allocation Chart
#
# | Task | Team Member | Start Date | End Date |
# | --- | --- | --- | --- |
# | Research and create a wireframe for the homepage using Sketch or Figma (Task 1) | John Doe (Project Manager), Jane Doe (Software Engineer) | January 15, 2023 | January 31, 2023 |
# | Create detailed sections on various topics for the blog section in WordPress (Task 2) | Alice Johnson (QA Engineer), Tom Brown (QA Engineer) | February 1, 2023 | February 14, 2023 |
# | Implement social media sharing capabilities using IntersectionObserver and API from social media platforms (Task 3) | Bob Smith (Designer) | January 20, 2023 | January 31, 2023 |
# | Optimize the website for search engines (SEO) by conducting a thorough analysis of Google Search Console and implementing SEO-friendly code (Task 4) | Jane Doe (Software Engineer), Alice Johnson (QA Engineer) | February 5, 2023 | February 14, 2023 |
# | Develop fast loading times and optimize for search engines (SEO) by optimizing HTML code using tools like Google Lighthouse (Task 5) | John Doe (Project Manager), Tom Brown (QA Engineer) | January 25, 2023 | January 31, 2023 |
# | Test and validate the website's functionality by using tools like Selenium or Cypress (Task 6) | Jane Doe (Software Engineer), Alice Johnson (QA Engineer) | February 10, 2023 | February 14, 2023 |
# | Implement responsive design by using Bootstrap framework (Task 7) | John Doe (Project Manager), Bob Smith (Designer) | January 20, 2023 | January 31, 2023 |
# | Test and validate the website's functionality by conducting thorough testing using tools like End-to-End Testing (E2ET) (Task 8) | Alice Johnson (QA Engineer), Jane Doe (Software Engineer) | February 5, 2023 | February 14, 2023 |
# | Finalize the development and deployment process by conducting comprehensive test suite using tools like Cypress or Playwright (Task 9) | John Doe (Project Manager), Jane Doe (Software Engineer) | January 25, 2023 | January 31, 2023 |
# | Launch and maintain the website by setting up analytics tools like Google Analytics to track user behavior and monitor performance metrics (Task 10) | Jane Doe (Software Engineer), Bob Smith (Designer) | February 15, 2023 | March 1, 2023 |
#
# Summary:
# The above chart outlines the strategic allocation of tasks for the Website project. Each task has been assigned to a team member based on their skills, availability, and current workload. The workload is evenly distributed across all team members, ensuring that no individual is overburdened while others are able to complete their tasks efficiently. This allocation also ensures that each task is completed within the specified deadlines, meeting the quality standards of the project.
#
# Rationale:
# The allocated tasks have been carefully considered based on the skills and expertise of each team member. Tasks such as researching and creating wireframes for the homepage and implementing social media sharing capabilities are assigned to team members with relevant technical expertise. The development and deployment process involves assigning tasks that require coding and testing skills, such as optimizing the website for search engines and developing fast loading times. Finally, tasks like testing and validation of the website's functionality require thorough testing skills.
#
# By following this allocation strategy, we can ensure that the Website project is completed on time, within budget, and to the required quality standards. This approach also promotes collaboration and knowledge sharing among team members, ensuring that everyone is working towards a common goal.
#
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#
#
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
